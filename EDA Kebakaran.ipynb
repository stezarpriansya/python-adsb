# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('processed-data-kejadian-kebakaran-2013.csv', encoding = "ISO-8859-1")
data.head(5)
# Out:
#    No                    Tanggal     Keterangan JKB       Sumber Informasi  \
# 0   1  01/Januari/2013  (Selasa)  Bencana Kebakaran        Petugas Pemadam
# 1   2  01/Januari/2013  (Selasa)  Bencana Kebakaran             Masyarakat
# 2   3  01/Januari/2013  (Selasa)  Bencana Kebakaran             Masyarakat
# 3   4  01/Januari/2013  (Selasa)  Bencana Kebakaran  Petugas Instansi Lain
# 4   5    02/Januari/2013  (Rabu)  Bencana Kebakaran        Petugas Pemadam
#
#   Waktu Informasi          Alamat Kejadian  RT   RW        Kelurahan  \
# 0           00:05  Jl. Angin Puyuh No. 76C    5   11    Semper Barat
# 1           05:00              Jl. H. Alit    8    3         Pekayon
# 2           10:00        Jl. Indra Loka VI    8    6   Wijaya Kusuma
# 3           00:00    Jl. Jiung No.49 Gg. N    1    3    Utan Panjang
# 4           19:30         Jln. Meruya Raya    9    7  Meruya Selatan
#
#            Kecamatan    ...     Objek BP Objek BUP Objek BI Objek KD Objek LN  \
# ...

# %%
#cek dimensi
data.shape
# Out:
# (1592, 44)

# %%
#cek tipe data
data.dtypes
# Out:
# No                                 int64
# Tanggal                           object
# Keterangan JKB                    object
# Sumber Informasi                  object
# Waktu Informasi                   object
# Alamat Kejadian                   object
#  RT                               object
#  RW                               object
# Kelurahan                         object
# Kecamatan                         object
# Wilayah                           object
# Objek Kejadian Awal               object
# Kode Objek Bencana                object
# Kategori Objek Bencana            object
# Objek Kejadian Lainnya            object
# Kode Objek Bencana Lainnya        object
# Kategori Objek Bencana Lainnya    object
# ID Bang                           object
# Jenis Bangunan                    object
# ID Sebab                          object
# Sebab Kejadian                    object
# Keterangan Sebab Kejadian         object
# Waktu Respon                      object
# ...

# %%
#cek kolom yang terdapat missing value
data.isna().any()
# Out:
# No                                False
# Tanggal                           False
# Keterangan JKB                    False
# Sumber Informasi                   True
# Waktu Informasi                   False
# Alamat Kejadian                   False
#  RT                                True
#  RW                                True
# Kelurahan                         False
# Kecamatan                         False
# Wilayah                           False
# Objek Kejadian Awal               False
# Kode Objek Bencana                 True
# Kategori Objek Bencana             True
# Objek Kejadian Lainnya             True
# Kode Objek Bencana Lainnya         True
# Kategori Objek Bencana Lainnya     True
# ID Bang                            True
# Jenis Bangunan                     True
# ID Sebab                           True
# Sebab Kejadian                     True
# Keterangan Sebab Kejadian          True
# Waktu Respon                       True
# ...

# %%
#mencari info dari tipe data tiap atribut
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 44 columns):
# No                                1592 non-null int64
# Tanggal                           1592 non-null object
# Keterangan JKB                    1592 non-null object
# Sumber Informasi                  1590 non-null object
# Waktu Informasi                   1592 non-null object
# Alamat Kejadian                   1592 non-null object
#  RT                               1095 non-null object
#  RW                               1112 non-null object
# Kelurahan                         1592 non-null object
# Kecamatan                         1592 non-null object
# Wilayah                           1592 non-null object
# Objek Kejadian Awal               1592 non-null object
# Kode Objek Bencana                1591 non-null object
# Kategori Objek Bencana            1591 non-null object
# Objek Kejadian Lainnya            70 non-null object
# ...

# %%
#descriptive analyst untuk data yang numerical
data.describe()
# Out:
#         JUMLAH SDM  Lama Operasi -  Hari  Lama Operasi - Jam  \
# count  1592.000000           1592.000000         1592.000000
# mean     30.206030            -25.911432            2.402638
# std      37.362347           1034.765827            3.675467
# min       0.000000         -41287.000000            0.000000
# 25%       5.000000              0.000000            0.000000
# 50%      12.000000              0.000000            0.500000
# 75%      40.750000              0.000000            3.000000
# max     254.000000             15.000000           23.000000
#
#        Lama Operasi -  Menit
# count           1.592000e+03
# mean           -3.730476e+04
# std             1.490063e+06
# min            -5.945328e+07
# 25%             5.000000e+00
# 50%             2.000000e+01
# 75%             3.500000e+01
# max             1.157000e+04

# %%
data['No'] = str(data['No'])
data['JUMLAH UNIT'] = str(data['JUMLAH UNIT'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 44 columns):
# No                                1592 non-null object
# Tanggal                           1592 non-null object
# Keterangan JKB                    1592 non-null object
# Sumber Informasi                  1590 non-null object
# Waktu Informasi                   1592 non-null object
# Alamat Kejadian                   1592 non-null object
#  RT                               1095 non-null object
#  RW                               1112 non-null object
# Kelurahan                         1592 non-null object
# Kecamatan                         1592 non-null object
# Wilayah                           1592 non-null object
# Objek Kejadian Awal               1592 non-null object
# Kode Objek Bencana                1591 non-null object
# Kategori Objek Bencana            1591 non-null object
# Objek Kejadian Lainnya            70 non-null object
# ...

# %%
grouped = data.groupby(['Survived', 'Pclass'])
