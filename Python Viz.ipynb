# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv("viz/df1.csv", index_col = 0)
df2 = pd.read_csv("viz/df2.csv")
df3 = pd.read_csv("viz/df3.csv")

# %% [markdown]
# ## Histogram

# %%
df1['A'].hist(bins=20)

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('dark_background')
df1['A'].hist(bins=20)

# %%
plt.style.use('ggplot')
df1['A'].hist(bins=20)

# %% [markdown]
# ## Area

# %%
df2.plot.area(alpha=0.4)

# %%
df2[['a','c']].plot.area(alpha=0.5) #alpha untuk transparasi

# %%
df2[['a','c']].plot.area(alpha=0.5, figsize=(5,3))  #figsize untuk memberikan ukuran figur

# %% [markdown]
# # BarPlot

# %%
df2.plot.bar()

# %%
df2['b'].plot.bar()

# %%
df2[['b', 'c']].plot.bar(stacked=True)

# %% [markdown]
# ## Line Plots

# %%
df1.plot.line(x=df1.index, y='B', figsize=(12,3), lw=1)
# df1.index

# %% [markdown]
# ## ScatterPlot

# %%
df1.plot.scatter(x='A', y='B')

# %%
 df1.plot.scatter(x='A', y='B', c='C', cmap='Greens', figsize=(12,5))#menampilkan C dengan perbedaan warna

# %%
 df1.plot.scatter(x='A', y='B', s=df1['C']*100, figsize=(12,5))
# Out:
# C:\Users\stezar059244\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\collections.py:853: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ## Box

# %%
df1.plot.box()

# %% [markdown]
# ## KDE

# %%
df2['a'].plot.kde()

# %%
df2.plot.density()
